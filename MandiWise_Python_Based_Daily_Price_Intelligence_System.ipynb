# %% [markdown]
# <a href="https://colab.research.google.com/github/mmalathi97-commits/Malathi.M/blob/main/MandiWise_Python_Based_Daily_Price_Intelligence_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MandiWise: Python-Based Daily Price Intelligence System

# %% [markdown]
# 📊  Data Analytics Project

# %% [markdown]
#  Domain: Agriculture Analytics

# %% [markdown]
# This project belongs to the Agriculture domain because it analyzes daily commodity prices from various mandis to generate market insights using data analytics techniques.

# %% [markdown]
# Project Objective

# %% [markdown]
# The main objective of this project is to analyze daily commodity prices from various mandis using Python in order to identify price trends, market variations, and key insights that can help farmers, traders, and policymakers make informed decisions.

# %% [markdown]
# # Dataset information
#
# Source : Government Open Data Portal – Data.gov.in
#
# Location :India (Various States and Agricultural Markets / Mandis across India)
#
# Year / Timeline :Data collected during the period 2023 to 2024.

# %% [markdown]
# # Stage 1:
#
# Problem Definition
#
# Agricultural commodity prices vary daily across different mandis due to factors such as demand and supply, seasonal production, and regional market conditions. These price fluctuations make it difficult for farmers, traders, and policymakers to make informed decisions.
#
# The problem addressed in this project is to analyze daily mandi commodity price data to identify price trends, variations across markets, and key insights using Python-based data analytics techniques.
#
# Dataset Selection
#
# The dataset used in this project is obtained from the Government Open Data Portal – Data.gov.in.
# It contains daily price details of various agricultural commodities from multiple mandis across India.
#
# The dataset includes important attributes such as:
#
# State
#
# District
#
# Market (Mandi)
#
# Commodity Name
#
# Minimum Price
#
# Maximum Price
#
# Modal Price
#
# Date
#
# This dataset was selected because it provides real-world agricultural market data suitable for performing data cleaning, analysis, and visualization using Python.

# %%
# Import Required Libraries

import pandas as pd              # For data manipulation and analysis
import numpy as np               # For numerical operations
import matplotlib.pyplot as plt  # For data visualization
import seaborn as sns            # For advanced data visualization
import warnings                  # To ignore warning messages

warnings.filterwarnings("ignore")

# %%
# Load the dataset from GitHub

import pandas as pd

url = ""

df = pd.read_csv(url)

# Display first 5 rows
df.head()

# %% [markdown]
# # Dataset description
